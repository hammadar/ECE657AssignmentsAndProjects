# %%
import torch
import torchvision
import utils


sizes = [3, 512, 512, 10] #define layers for MLP
mlp = utils.MLP(sizes)
mlp.train()

cnn1 = utils.CNN(1) #for first CNN network
cnn1.train()

cnn2=utils.CNN(2) #for second CNN network
cnn2.train()
# Out:
# Epoch 1/5
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3193 - categorical_accuracy: 0.0983 - val_loss: 2.3308 - val_categorical_accuracy: 0.1000
# Epoch 2/5
# 313/313 [==============================] - 1s 4ms/step - loss: 2.3002 - categorical_accuracy: 0.1137 - val_loss: 2.2806 - val_categorical_accuracy: 0.1000
# Epoch 3/5
# 313/313 [==============================] - 1s 4ms/step - loss: 2.2565 - categorical_accuracy: 0.1434 - val_loss: 2.2411 - val_categorical_accuracy: 0.1502
# Epoch 4/5
# 313/313 [==============================] - 1s 4ms/step - loss: 2.1844 - categorical_accuracy: 0.1625 - val_loss: 2.1501 - val_categorical_accuracy: 0.1500
# Epoch 5/5
# 313/313 [==============================] - 1s 4ms/step - loss: 2.1238 - categorical_accuracy: 0.1705 - val_loss: 2.0978 - val_categorical_accuracy: 0.1871
# Epoch 1/5
# ...
